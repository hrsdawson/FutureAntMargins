# %%
import cosima_cookbook as cc

# %%
db = '/g/data/e14/hd4873/access-om2-01/project03_misc_data/databases/SSP2100_experiments_nodaily.db'
session = cc.database.create_session(db)

# %%
directory_list=['/g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091_ssp585',
                '/g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091_ssp585_mw/',
                '/g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091_ssp245',
                '/g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v13_ryf9091_ssp245_mw',
               ]
cc.database.build_index(directory_list, session, force=True)
# Out:
# Indexing experiment: 01deg_jra55v13_ryf9091_ssp585
# 100%|██████████| 890/890 [04:01<00:00,  3.68it/s]
# Indexing experiment: 01deg_jra55v13_ryf9091_ssp585_mw
# 100%|██████████| 871/871 [04:11<00:00,  3.46it/s]
# Indexing experiment: 01deg_jra55v13_ryf9091_ssp245
# 100%|██████████| 890/890 [03:43<00:00,  3.98it/s]
# Indexing experiment: 01deg_jra55v13_ryf9091_ssp245_mw
# 100%|██████████| 890/890 [04:09<00:00,  3.56it/s]
# 3541

# %% [markdown]
# Original:

# %%
directory_list=['/scratch/oz91/hd4873/access-om2/archive/01deg_jra55v13_ssp245_windthermalmw',
                '/scratch/e14/hd4873/access-om2/archive/01deg_jra55v13_ssp245_windthermal',
                '/scratch/e14/hd4873/access-om2/archive/01deg_jra55v13_ssp585_windthermal',
                '/scratch/e14/hd4873/access-om2/archive/01deg_jra55v13_ssp585_windthermalmw'
               ]
cc.database.build_index(directory_list, session, force=True)
# Out:
# Indexing experiment: 01deg_jra55v13_ssp245_windthermalmw
# ...
# 100%|██████████| 791/791 [07:07<00:00,  1.85it/s]
# Indexing experiment: 01deg_jra55v13_ssp245_windthermal
# ...
# 100%|██████████| 46/46 [00:28<00:00,  1.62it/s]
# Indexing experiment: 01deg_jra55v13_ssp585_windthermal
# ...
# 100%|██████████| 46/46 [00:24<00:00,  1.89it/s]
# Indexing experiment: 01deg_jra55v13_ssp585_windthermalmw
# ...
# 100%|██████████| 57/57 [00:27<00:00,  2.04it/s]
# 7940
