# %%
import cosima_cookbook as cc

# %%
db = '/g/data/e14/hd4873/access-om2-01/project03_cmip6_forcing/databases/ssp585_incomplete.db'
session = cc.database.create_session(db)

# %%
directory_list=['/scratch/e14/hd4873/access-om2/archive/01deg_jra55v13_ssp585_windthermal',
               ]
cc.database.build_index(directory_list, session)#, force=True)
# Out:
# Indexing experiment: 01deg_jra55v13_ssp585_windthermal
# ...
# 100%|██████████| 248/248 [01:57<00:00,  2.10it/s]
# 1248

# %%
/g/data/e14/hd4873/access-om2-01/project03_cmip6_forcing
